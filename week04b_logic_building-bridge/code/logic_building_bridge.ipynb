# %% [markdown]
# # Logic Building

# %% [markdown]
# ## 🧠 The 5-Step Method

# %% [markdown]
# - Restate — problem ko apne shabdon mein bolo. "Mujhe kya input mil raha hai, aur kya output chahiye?"
# - Example first — ek concrete input lo, use KAAGAZ par HAATH se solve karo. Answer likho.
# - Pseudocode — solution ke steps plain English/Hinglish mein likho. Abhi Python NAHI.
# - Translate — har English step ko ek Python line mein badlo.
# - Trace (dry run) — wahi example lo, code ko line-by-line chalao, har variable ki value ek table mein likho.

# %% [markdown]
# ## 🔀 Order kyun aisa hai?

# %% [markdown]
# - Building the skill (poore week ka order): Trace (read) → Pseudocode (plan) → Write → Trace (debug)
#
# - Solving any one problem (ek problem ka order): Understand → Pseudocode → Write → Trace.

# %% [markdown]
# ## LOGIC CLASS 1 — Trace First: Code ko "chalana" seekho (dimaag mein)

# %% [markdown]
# 👨‍🏫 Concept 1 — Trace table kya hai?

# %% [markdown]
# 📖 Technical definition — Tracing (dry run): Tracing is manually stepping through code one line at a time, recording the value of every variable after each line, to predict the program's behavior without running it.

# %%
total = 0
for n in [3, 5, 2]:
    total = total + n
print(total) ## >> 10
# Out:
# 10

# %% [markdown]
# step  | total  | n
# shuru | 0      | -
# loop 1| 0      | 3
# loop 1| 3      | 3
# loop 2| 3      | 5
# loop 2| 8      | 5
# loop 3| 8      | 2
# loop 3| 10     | 2
# print |10      | _

# %% [markdown]
# 👨‍🏫 Concept 2 — Ab thoda mushkil (nested + if)

# %%
count = 0
for word in ["hi", "sun", "go"]:
    for letter in word: # "go"
        if letter in "aeiou": ## true
            count = count + 1
     
print(count) ## 3
# Out:
# 3

# %%
count = 0
for word in ["hi", "sun", "go", "hello"]:
    for letter in word: # "go"
        if letter in "aeiou": ## true
            count = count + 1
     
print(count) ## 5
# Out:
# 5

# %%
count = 0
for word in ["hi", "sun", "goiou", "hello"]:
    for letter in word: # "go"
        if letter in "aeiou": ## true
            count = count + 1
     
print(count) ## 8
# Out:
# 8

# %% [markdown]
# step

# %% [markdown]
# Homework:
#
#
# # 1 : question:
# x = 10
# for i in range(3):
#     x = x - 2
# print(x) ## ?
#
# # 2
# result = ""
# for c in "cat":
#     result = c + result
# print(result) ## ?
#
# # 3
# nums = [4, 1, 7, 3]
# biggest = nums[0]
# for n in nums:
#     if n > biggest:
#         biggest = n
# print(biggest) ## ?
#
# # 4
# s = 0
# for i in range(1, 6):
#     if i % 2 == 0:
#         s = s + i
# print(s) ## ?

# %% [markdown]
# ## Extra Homework

# %% [markdown]
# 🟢 Warm-up (1–10): ek variable / simple loop / basic string

# %% [markdown]
# Q1 <br>
# EN: Trace x step by step. What prints? <br>HI: x ko step-by-step trace karo. Kya print hoga?

# %%
x = 5
x = x + 3
x = x * 2
print(x) ## 16
# Out:
# 16

# %% [markdown]
# 🟡 Core (11–22): loop + if / accumulator / list

# %% [markdown]
# Q3
#
# EN: Trace biggest. <br>
# HI: biggest trace karo.

# %%
biggest = 0
for n in [3, 7, 2, 9, 4]:
    if n > biggest: ## False
        biggest = n

print(biggest) ## 9
# Out:
# 9

# %% [markdown]
# 🟠 Challenge (23–32): while / break / continue / nested

# %% [markdown]
# Q32
#
# EN: Tuples are unpacked in the loop. Trace total. <br>
# HI: Loop mein tuples unpack hote hain. total trace karo.

# %%
pairs = [(1, 2), (3, 4), (5, 6)]
total = 0
for a, b in pairs: ## [(1, 2), (3, 4), (5, 6)]
    total = total + (a * b)

print(total) ## 44
# Out:
# 44

# %% [markdown]
# 🔴 Advanced (33–40): dict / set / comprehension

# %%
import random

random.randint(33, 40)
# Out:
# 38

# %% [markdown]
# Q38
#
# EN: What does set() do to duplicates? <br>HI: set() duplicates ka kya karta hai?

# %%
nums = [1, 2, 2, 3, 3, 3]
print(len(set(nums)))
# Out:
# 3

# %% [markdown]
# ## LOGIC CLASS 2 — Pseudocode: Python se PEHLE English mein socho

# %% [markdown]
# 👨‍🏫 Concept 1 — Problem: "3 numbers mein sabse bada"

# %% [markdown]
# step1: Restate: I have 3 number then get max number / Mere pass 3 numbers hain usmese bada numberr lena hain
#
# step2: Example: a =5, b=7, c=4, >>>>> answer b=7
#
# step3: Pseudocode (it's your choise to use your language to write steps of problem to exicute before writing python code)

# %% [markdown]
# ## step 3 : Pseudocode
#
#
# 1>> get 3 numbers a,b,c
# 2 >> consider a is max number
# 3>>> is b is greter than max number if yes then mx number is b else max number
# 4>>> is c is greter than max number if yes then max number is c else  max number
# 5>> sho max number to user

# %%
## Step 4

## a = 4
## b = 9
## c = 3

a,b,c = 4,9,3

max_number = a

if b > max_number:  ###  9 > 4
    max_number = b

if c > max_number: ## 3 > 9
    max_number = c

print("Maximum number is ", max_number)
# Out:
# Maximum number is  9

# %% [markdown]
# ## Step 5 Trace (dry run)
#
#
# steps   a   b   c   max_number
# 1       4   9   3
# 2       4   9   3   4
# 3       4   9   3   9
# 4       4   9   3   9
#
# 5       "Maximum number is 9"

# %%
a = 4
b = 9
c = 3


a > b >>> a

# %%
nums = [1,2,3]

nums.sort()

print(nums[-1])
# Out:
# 3

# %% [markdown]
# ## LOGIC CLASS 3 — The Accumulator Pattern (count / sum / max / build)

# %% [markdown]
# 👨‍🏫 Concept 1 — Pattern ka shape

# %% [markdown]
# 1. ek "box" banao aur usme starting value daalo   (accumulator)
# 2. har item par loop chalao
# 3.    box ki value ko update karo (add / count / compare)
# 4. loop ke baad box ko use karo (print)

# %% [markdown]
# 👨‍🏫 Concept 2 — Same pattern, 4 problems

# %% [markdown]
# 1: Sum

# %%
numbers = [1,2,4,5,6,7]

sum = 0
for num in numbers:
    sum +=num
print("Sum of all numbers: ", sum)
# Out:
# Sum of all numbers:  25

# %% [markdown]
# 2: Count (kitne even hain?):

# %%
numbers = [1,2,4,5,6,7]
count = 0

for num in numbers:
    if num % 2 == 0:
        count +=1

print('Total even values found : ', count)
# Out:
# Total even values found :  3

# %% [markdown]
# 3: Count vowels in a string:

# %%
word = "education"
count = 0                 # box
for letter in word:
    if letter in "aeiou":
        count = count + 1
print(count)              # 5
# Out:
# 5

# %% [markdown]
# 4: Max (bina max() ke):

# %%
nums = [4, 9, 2, 11, 6]
biggest = nums[0]         # box = pehla item
for n in nums:
    if n > biggest:
        biggest = n       # update jab bada mile
print(biggest)            # 11
# Out:
# 11

# %% [markdown]
# ✍️ Homework — Har ek accumulator pattern se
# Ek list ke saare numbers ka product (guna) nikalo.
# Ek sentence mein kitne words hain ginno (hint: .split()).
# Ek list mein sabse chhota number dhoondho (bina min()).
# "hello" ko reverse karke naya string banao (accumulator = "").

# %% [markdown]
# ## LOGIC CLASS 4 — The Flag / Search Pattern

# %% [markdown]
# 👨‍🏫 Concept 1 — Flag kya hai?

# %% [markdown]
# 📖 Technical definition — Flag variable: A flag is a boolean variable that starts with an assumed answer (usually True or False) and is flipped when the loop finds evidence to the contrary.

# %% [markdown]
# 👨‍🏫 Concept 2 — "Kya list mein 7 hai?"

# %%
## Test 1
# numbs = [3,5,6,8,2,7,9,3]
# find_value = 7


## Test 2
numbs = [3,5,6,8,2,7,9,3]
find_value = 11

found  = False 

for num in numbs:
    if num == find_value:
        found = True

print(f"is {find_value} present : {found}")
# Out:
# is 11 present : False

# %% [markdown]
# ✍️ Homework
# Check karo ek list mein koi negative number hai kya (flag).
# Check karo ek word mein koi vowel hai kya.
# range(2, 30) mein saare prime numbers print karo (Concept 3 ko loop mein daalo).
# Ek list of names mein "Asha" hai kya, aur agar hai toh us par kaunse index par hai (hint: enumerate).

# %% [markdown]
# ## LOGIC CLASS 5 — Mini Project: Sab kuch jodo (Project class)

# %% [markdown]
# - Restate — problem ko apne shabdon mein bolo. "Mujhe kya input mil raha hai, aur kya output chahiye?"
# - Example first — ek concrete input lo, use KAAGAZ par HAATH se solve karo. Answer likho.
# - Pseudocode — solution ke steps plain English/Hinglish mein likho. Abhi Python NAHI.
# - Translate — har English step ko ek Python line mein badlo.
# - Trace (dry run) — wahi example lo, code ko line-by-line chalao, har variable ki value ek table mein likho.

# %% [markdown]
# Buss Problem: Create FizzBuzz Game with user range

# %% [markdown]
# - 1: Restate: user se input lenge ek range, 3 matlab fizz, 5 matlab buzz, or number devided by 3 and 5 then fizbuzz
# - 2: Eample: range(1,user_range_end_value), 3=Fizz, 5=Buzz, 15=FizzBuzz, or only number print
# - 3: Pseudocode:
#         1. user se range  input lo
#         2. 1 se user range tak loop chalao
#         3. loop number 3 and 5 se divide ho to fizzbuzz
#         4. loop number 3 se divide ho to fizz
#         5. loop number 5 se divide ho to buzz
#         6: nahi to number de do

# %% [markdown]
# 4: Translate in python and
# 5: Trace

# %%
end_loop_value = int(input("Enter end value of fizzBuzz game")) ## 20

for i in range(1, end_loop_value): ## 1,20
    if i%3 == 0 and i%5 == 0:
        print("FizzBuzz")
    elif i%3 == 0:
        print("Fizz")
    elif i%5 == 0:
        print("Buzz")
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14

# %% [markdown]
# ## Trace error

# %%
end_loop_value = int(input("Enter end value of fixxBuzz game")) ## 20

for i in range(1, end_loop_value): ## 1,20
    if i%3 == 0 and i%5 == 0:
        print("FizzBuzz")
    elif i%3 == 0:
        print("Fizz")
    elif i%5 == 0:
        print("Buzz")
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
